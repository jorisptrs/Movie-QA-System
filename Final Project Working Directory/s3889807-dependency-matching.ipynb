# %% [markdown]
# # Advanced Question Analysis
#
# The goal of this assignment is to write a more flexible version of the interactive QA system. As in the previous assignment, the system should be able to take a question in natural language (English) as input, analyse the question, and generate a SPARQL query for it.
#
# ## Assignment  // Additional requirements
#
# * Make sure that your system can analyse at least two more question types. E.g. questions that start with *which*, *when*, where the property is expressed by a verb, etc.
# * Apart from the techniques introduced last week (matching tokens on the basis of their lemma or part-of-speech), also include at least one pattern where you use the dependency relations to find the relevant property or entity in the question.
# * Include 10 examples of questions that your system can handle, and that illustrate the fact that you cover additional question types
#
# ## Examples
#
# Here is a non-representative list of questios and question types to consider. See the list with all questions for more examples
#
# * For what movie did Leonardo DiCaprio win an Oscar?
# * How long is Pulp Fiction?
# * How many episodes does Twin Peaks have?
# * In what capital was the film The Fault in Our Stars, filmed?
# * In what year was The Matrix released?
# * When did Alan Rickman die?
# * Where was Morgan Freeman born?
# * Which actor played Aragorn in Lord of the Rings?
# * Which actors played the role of James Bond
# * Who directed The Shawshank Redemption?
# * Which movies are directed by Alice Wu?

# %%
import spacy

nlp = spacy.load("en_core_web_sm") # this loads the model for analysing English text

# %% [markdown]
# ## Dependency Analysis with Spacy
#
# All the functionality of Spacy, as in the last assignment, is still available for doing question analysis.
#
# In addition, also use the dependency relations assigned by spacy. Note that a dependency relation is a directed, labeled, arc between two tokens in the input. In the example below, the system detects that *movie* is the subject of the passive sentence (with label nsubjpass), and that the head of which this subject is a dependent is the word *are* with lemma *be*.

# %%
question = 'Which movies are directed by Alice Wu?'

parse = nlp(question) # parse the input 

for word in parse : # iterate over the token objects 
    print(word.lemma_, word.pos_, word.dep_, word.head.lemma_)
# Out:
# which DET det movie
# movie NOUN nsubjpass direct
# be AUX auxpass direct
# direct VERB ROOT direct
# by ADP agent direct
# Alice PROPN compound Wu
# Wu PROPN pobj by
# ? PUNCT punct direct

# %% [markdown]
# ## Phrases
#
# You can also match with the full phrase that is the subject of the sentence, or any other dependency relation, using the subtree function

# %%
def phrase(word, remove = "") :
    children = []
    for child in word.subtree :
        children.append(child.text.replace(remove,''))
    return " ".join(children)
        
for word in parse:
    if word.dep_ == 'nsubjpass' or word.dep_ == 'agent' :
        phrase_text = phrase(word)
        print(phrase_text)
# Out:
# Which movies
# by Alice Wu

# %% [markdown]
# ## Visualisation
#
# For a quick understanding of what the parser does, and how it assigns part-of-speech, entities, etc. you can also visualise parse results. Below, the entity visualiser and parsing visualiser is demonstrated.
# This code is for illustration only, it is not part of the assignment.

# %%
from spacy import displacy

question = 'In how many films is Pulp Fiction?'

parse = nlp(question)

displacy.render(parse, jupyter=True, style="ent")

displacy.render(parse, jupyter=True, style="dep")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In how many films is
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pulp Fiction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ?</div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="af5b5c0cdb954b269c00c8cab2957a08-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">how</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">films</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Pulp</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Fiction?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af5b5c0cdb954b269c00c8cab2957a08-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af5b5c0cdb954b269c00c8cab2957a08-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af5b5c0cdb954b269c00c8cab2957a08-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af5b5c0cdb954b269c00c8cab2957a08-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af5b5c0cdb954b269c00c8cab2957a08-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af5b5c0cdb954b269c00c8cab2957a08-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af5b5c0cdb954b269c00c8cab2957a08-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af5b5c0cdb954b269c00c8cab2957a08-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af5b5c0cdb954b269c00c8cab2957a08-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af5b5c0cdb954b269c00c8cab2957a08-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-af5b5c0cdb954b269c00c8cab2957a08-0-5" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-af5b5c0cdb954b269c00c8cab2957a08-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,266.5 L1103.0,254.5 1087.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# # Assignment Submission
# ### S3889807

# %% [markdown]
# ## Code from last assignment
# - Get wikidata IDs
# - Generate SPARQL Queries
# - Connect to wikidata endpoint to get SPARQL results

# %%
import requests

def get_wikidata_ids(name, search_property = False):
    """
    Returns a list of ID dictionaries (with labels and possibly descriptions)
    for a given name, either looking for entities or properties (set search_property:=True for the latter)
    Each dict contains keys: 'id', 'label', and possibly 'description'.
    If a description cannot be found, it will not be included in the dict.
    """
    all_results = []
    
    url = 'https://www.wikidata.org/w/api.php'
    params = {'action':'wbsearchentities', 
              'language':'en',
              'format':'json'}
    
    # add a param to the request if it needs to look for a property
    if search_property:
        params['type'] = 'property'
    
    params['search'] = name
    json = requests.get(url,params).json()
    
    # extract only the useful data from the json file
    try:
        for result in json['search']:
            # append an empty dictionary
            all_results.append({})
            # add the ID and label
            all_results[-1]['id'] = result['id']
            all_results[-1]['label'] = result['label']
            # add a description if it exists
            if 'description' in result.keys():
                all_results[-1]['description'] = result['description']
    except:
        # no results
        pass
    return all_results

# %%
def generate_sparql_query(entity_id, property_id):
    """ 
    Returns string with entity id and property id in place as a SPARQL query
    """
    query = f'''SELECT ?answerLabel WHERE {{
                wd:{entity_id} wdt:{property_id} ?answer.
                SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}
                }}'''
    return query

def getSPARQLresults(query):
    """
    Relates to previous assignment. Return results (string) for a SPARQL query.
    The format is arbitrary can can be changed as desired.
    """
    url = 'https://query.wikidata.org/sparql'
    results = ""
    data = requests.get(url, params={'query': query, 'format': 'json'}).json()
    for item in data['results']['bindings']:
        for var in item :
            results+=('{}\t{}\n'.format(var,item[var]['value']))
            
    return results

# %%
"""
Helpers
"""

def children(q, head, includeSelf):
    """
    Returns direct children and self if needed
    """
    children = []
    for token in q:
        if (token != head and token.head == head) or (includeSelf and token == head):
            children.append(token)
    return children

def get_root(doc):
    """
    Return the root of the dependency tree
    in a given nlp-parsed sentence (root)
    """
    for word in doc:
        if word.dep_ == "ROOT":
            return word
        
def phrase(word, remove = ""):
    """
    Given code: Return the phrase that the given word heads
    """
    children = []
    for child in word.subtree:
        children.append(child.text.replace(remove,''))
    return " ".join(children)

def findDep(q, dep):
    """
    Returns the first token corresponding to the dependency. Else false
    """
    for word in q:
        if word.dep_ in dep:
            return word
    return False

def nominalize(word):
    nom_dict = {
        'much' : 'quantity',
        'long' : 'duration',
        'many' : 'quantity',
        'often' : 'frequency',
        'birthday' : 'date of birth'
    }
    if word in nom_dict:
        return nom_dict[word]
    else:
        return word

# %%
### Entity extraction functions ###
import re
import spacy
from spacy.tokenizer import Tokenizer


def get_named_entities(doc):
    """ 
    spacy has entity recognition in-built, which might work well
    for names, but not for multi-word named entities (like movie titles)
    """
    return doc.ents

def custom_tokenizer(nlp):
    """
    spacy gives the programmer the ability to customize the tokenizer using regex.
    This one specifically looks for sets of contiguous words that all have an upper-
    case letter (i.e. that are titled). This can alternatively be done by using spacy's
    istitle() function on all combinations of words, but that is less efficient.
    e.g. "How I Met Your Mother" will be a single token using this.
    """
    token_re = re.compile(r"([A-Z][a-z']*(?:[\s][A-Z][a-z]+)*)")
    return Tokenizer(nlp.vocab, token_match = token_re.findall)

def get_entity_complex(q_str):
    """
    calls the above function on a query string
    """
    nlp.tokenizer = custom_tokenizer(nlp)
    doc = nlp(q_str)
    # return the last named entity since the needed 
    # entity is likely at the very end of the string
    return doc[-1].text

def get_closest_proper_noun(root, remove = ''):
    """
    It is often the case that the proper noun
    that is most closely associated with the root
    is the most relevent entity in question.
    This is a recursive function starting at the 
    root and doing a BFS through the tree
    """
    pn = None
    for child in root.children:
        if child.pos_ == 'PROPN':
            pn = phrase(child, remove)
            return pn
        
        pn = get_closest_proper_noun(child)
        if pn is not None:
            break
    
    return pn

### Parser for natural language query ###

def preprocess(query):
    """
    Preprocessing for looking for entities using
    non-dependency methods. This is not strictly
    necessary, but makes it slightly less brittle
    wrt the orthography of the sentence.
    """
    query = query.replace('?','')
    query = query.replace(query[0], query[0].lower(), 1)
    return query

def get_entities(query):
    """
    Return the possible entities of a given English query.
    The possibilites are:
        Proper noun phrase closest to root
        Named entities according to SPACY
        Regex-found entities (titled words in a row)
    """
    nlp = spacy.load("en_core_web_sm") # this loads the model for analysing English text
    entities = []
    
    doc = nlp(query)
    
    root = get_root(doc)
    entities.append(get_closest_proper_noun(root))
    
    query = preprocess(query)
    entities += [str(e) for e in get_named_entities(doc)]
    entities.append(get_entity_complex(query))
    
    entities = [str(e) for e in entities if " 's" not in e]
    
    return list(set(entities))

# %%
### Property Extraction functions ###
def reduce_based_on_ids(id_list):
    """
    If there are multiple ways of getting a list of properties,
    then they may be repeated. This simply removes duplicates,
    while not changing the relative order within the input list.
    """
    id_set = {}
    for obj in id_list:
        id_set[obj['id']] = obj

    return list(id_set.values())

def q_type_addition(doc):
    if doc[0].dep == 'prep' or doc[len(doc)-1].dep == 'prep':
        return True
    return False

def q_type_binary(doc):
    return doc[0].lemma_ in ['be', 'do', 'have']

"""Select question type"""
def questionType(doc):
    options = {
            'What' : whatOrWho,
            'Who' : whatOrWho,
            'When' : whenOrWhere,
            'Where' : whenOrWhere,
            'Howlong' : howLong,
            'Howmany' : howMany}
    if (q[0].text+q[1].text in options):
        options[q[0].text+q[1].text](q)
    elif (q[0].text in options):
        options[q[0].text](q)
    else:
        print("question type not supported, but we'll try...")
        passive(q)

def get_root_related_props(doc, entity):
    """
    Several methods to try and get properties with
    respect to the root of the question.
    
    ps <- list of possible properties
    For each child in root:
        (i) it cannot be a property if it is the entity
        (ii) it cannot be a property if it is a question word (w-word)
        (iii) if it is a nominal subject, add it to ps
        (iv) if it is a direct object, add it to ps
        (v) if it is an adjective, add it to ps
    If the root itself is not a simple word, add it to ps (e.g. if root := 'direct')
    
    return list of possible properties.
    
    Note: The lemmas and the phrases are added in order to make sure
          multi-word properties (e.g. 'voice actor') are also considered
    """
    ps = []
    root = get_root(doc)

    for child in root.children:
        if phrase(child) == entity:
            continue
        if child.text.lower() in ['who', 'what', 'when', 'how', 'which']:
            continue
        if child.dep_ == 'nsubj':
            ps.append(phrase(child))
            ps.append(child.text)
        if child.dep_ == 'dobj':
            ps.append(phrase(child))
            ps.append(child.text)
        if child.pos_ == 'ADJ':
            ps.append(nominalize(child.lemma_))
            ps.append(child.text)
            ps.append(child.lemma_)
    if root.lemma_ not in ['be', 'have', 'do']:
        ps.append(root.text)
        ps.append(root.lemma_)
    return ps

def get_properties(q, entity):
    """
    Returns list of possible properties (list of strings)
    """
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(q)
    
    ps = get_root_related_props(doc, entity)

    # remove all Nones
    return [x for x in ps if x is not None]

# %%
### Functions that are majorly hueristic/custom ###

def entity_related_to_movies(entity_list):
    """
    Given a list of dictionaries with information about the entity,
    check if the description contains a word that is related to a movie.
    These have been chosen based on wordnet's synsets. This can easily be
    extended or made more complex using nltk, but kept straightforward for now
    as it works well enough. This helps remove non-relevent entities that have
    with the same name, but not related to movies (e.g. Lord of the Rings book series)
    """
    valid = []
    movie_relation = ['movie', 'film', 'picture', 'moving picture', 'motion', 'pic', 'flick', 'TV',
                      'television', 'show', 'animation', 'animation']
    character_relation = ['fiction', 'fictitious', 'character']
    actor_relation = ['actor', 'actress', 'thespian']
    music_relation = ['musician', 'music', 'score', 'compose', 'song']
    
    all_relations = []
    all_relations += movie_relation
    all_relations += character_relation
    all_relations += actor_relation
    all_relations += music_relation
    
    for word in all_relations:
        for e in entity_list:
            if 'description' in e.keys():
                if word in e['description']:
                    if e not in valid:
                        valid.append(e)
                    
    return valid

# %%
import time

def pipeline(query, moderated = False):
    """
    Combines the above functions to create a pipeline to answer questions.
    
    Input: English string of the form "Who/What was/is/were (the) X of Y?"
    Output: Result of that query if found

    Often if there are too many queries sent to the endpoint at once,
    it will return none, so an optional boolean moderation is added
    to add an artificial 0.5 seconds between each request. This can be slower
    but has a lower chance of producing a request-related error. If an error
    occurs, try running with moderated = True
    """
    result = ''
    
    # get entities
    entities = get_entities(query)

    entities += [entity.replace("the ", "") for entity in entities]
    entities += [entity.replace("'s", "").strip() for entity in entities]
    entities = list(set(entities))
    entities = sorted(entities, key=len, reverse=True)
#     print(entities)
    entity_ids = []
    for entity in entities:
        entity_ids += entity_related_to_movies(get_wikidata_ids(entity))
    
    entity_ids = reduce_based_on_ids(entity_ids)
#     entity_ids = sorted(entity_ids, key=len, reverse=True)
#     print(entity_ids)
    
    # get properties
    properties = get_properties(query, entity)
    
    property_ids = []
    for p in properties:
        property_ids += get_wikidata_ids(p, True)
     
    # remove duplicates
    property_ids = reduce_based_on_ids(property_ids)
   
    # wrap in a try/except to help with request errors
    try:
        # for each combination of entities and properties
        # it is likely that the entities and properties
        # are sorted by relevence/similarity by wikidata
        # so return the first result that it finds. This
        # is not guaranteed however
        for entity_id in entity_ids:
            for property_id in property_ids:
#                 print(entity_id['label'], property_id['label'])
                # general SPARQL query
                sparql_query = generate_sparql_query(entity_id['id'], property_id['id'])
                result = getSPARQLresults(sparql_query)

                # check if there is a result
                if result is not None and result!='':
                    print("Closest answer:")
                    print(f"        entity: {entity_id['label']}")
                    print(f"      property: {property_id['label']}\n")
                    return result

                if moderated:
                    time.sleep(0.75)
                    
    except:
        print("Error while searching!")
        if not moderated:
            print("Attempting moderated search!")
            return pipeline(query, moderated = True)
        
        else:
            pass # goes directly to final return statement
            
    return "Answer not found"

# %% [markdown]
# ## Question handling
#
# This QA system should be able to handle questions about movies of several types, but specifically desiged to be able to work with the following, with X being the property and Y being the entity:
# - Who/What/When/etc was/is/were the/a/an X of Y? (from previous assignment, more passive, noun properties)
# - Who/What/When/etc was/is/were Y X? (similar to above, more active, verb properties)
# - How X is Y? (similar questions that use adjective properties)
#
# The following are pairs of questions that the system is able to answer. These are in pairs to show that the same question that is phrased differently (as long as it follows an above format) should give the same answer. A noun property (e.g. height) can be translated to a adjective property (e.g. tall). Similarly, a verb property (acted) can be translated to a noun property (actor).

# %%
# qs = ['Who directed The Shawshank Redemption?'
#      ,'Who is the director of The Shawshank Redemption?'
      
#      ,'What is the birth date of Alan Rickman?'
#      ,'When was Alan Rickman born?'
      
#      ,'What is the height of Amitabh Bachchan?'
#      ,'How tall is Amitabh Bachchan?'
      
#      ,'What is the publication date of The Dark Knight?'
#      ,'When was The Dark Knight published?'
     
#      ,'Who acted as Gollum?'
#      ,'Which actor played Gollum?'
     
#      ,'What is the length of Interstellar?'
#      ,'How long does Interstellar run?'
#     ]
# q11 = '''When did Alan Rickman die?'''
# q12 = '''When was Pulp Fiction published?'''
# q13 = '''Where was Morgan Freeman born?'''
# q14 = '''Where does Home Alone originate?'''
# q15 = '''Which movies are directed by Alice Wu?'''
# q16 = '''How long is Pulp Fiction?'''
# q17 = '''How many episodes does Twin Peaks have?'''
# q18 = '''How long is Interstellar?'''
# q19 = '''Which character was married by Aragorn'''
# q20 = '''Which character did Aragorn marry?'''
# for i in range(12,20):
#     continue
#     qs.append(globals()['q'+str(i)])
    
# for q in qs:
#     print(f"Query: {q}")
#     print(pipeline(q))
#     print("\t**********\n")

# %%
print(pipeline("When was Kiki's Delivery Service published?"))
# Out:
# Closest answer:
#         entity: Kiki's Delivery Service
#       property: publication date
#
# answerLabel	1989-07-29T00:00:00Z
# answerLabel	1998-05-23T00:00:00Z
# answerLabel	2004-03-31T00:00:00Z

# %%
from run_qs import get_q_list

qs = [q[0] for q in get_q_list()]

total_ans = 0
not_found = 0

f = open('answerlist.txt', 'w', encoding = 'utf-8')
f.write('No|Query|Answer\n')

for q in qs:
    print(f'{total_ans}) Query: {q}')
    ans = ''
    try:
        ans = pipeline(q)
    except:
        ans = 'Error'
        not_found += 1
    
    ans = ans.replace('answerLabel\t', "").strip()
    ans = ans.replace('\n', ", ").strip()
    
    try:
        f.write(f'{total_ans}|{q}|{ans}\n')
    except:
        print("Could not write to file")
        
    if ans == 'Answer not found':
        not_found += 1
    total_ans += 1
    
    print (f'\nAnswer: {ans}\n')

f.close()

print(f'Questions queried: {total_ans}')
print(f'Not found ratio: {not_found/total_ans}')
# Out:
# 0) Query: What movie won best picture in the 2020 Academy Awards?
#
# Answer: Answer not found
#
# 1) Query: Who voices Nala in the 2019 version of The Lion King?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 2) Query: What was the budget for Avengers: Endgame?
# Closest answer:
#         entity: The Avengers
#       property: cost
#
#
# Answer: 220000000
#
# 3) Query: Which is the longest Jim Carrey movie?
#
# Answer: Answer not found
#
# 4) Query: What movie(s) feature both Jack Nicholson and Meryl Streep?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 5) Query: Which director has been nominated most for the Best Director Academy Award?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 6) Query: What is the name of the actor who's father was a hitman?
#
# Answer: Error
#
# 7) Query: What movie(s) did M. Night Shyamalan direct before the year 2000?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 8) Query: What are the top three best worldwide grossing animated movies?
#
# Answer: Error
#
# 9) Query: Which actors have portrayed the character James Bond?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 10) Query: What is the movie The Avengers about?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: The Avengers
#       property: director
#
#
# Answer: Joss Whedon
#
# 11) Query: Where was Titanic shot?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 12) Query: What year did Grease come out?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Grease
#       property: followed by
#
#
# Answer: Grease 2
#
# 13) Query: How many awards did Titanic win?
# Closest answer:
#         entity: Titanic
#       property: award received
#
#
# Answer: Academy Award for Best Picture, Academy Award for Best Director, Academy Award for Best Original Song, Academy Award for Best Cinematography, Academy Award for Best Costume Design, Academy Award for Best Production Design, Academy Award for Best Film Editing, Academy Award for Best Visual Effects, Academy Award for Best Sound Editing, Japan Academy Prize for Outstanding Foreign Language Film, Golden Globe Award for Best Director, National Film Registry, Academy Award for Best Sound, Golden Globe Award for Best Motion Picture – Drama, Saturn Award for Best Supporting Actress, Screen Actors Guild Award for Outstanding Performance by a Female Actor in a Supporting Role, Golden Globe Award for Best Original Score, Golden Globe Award for Best Original Song, National Board of Review: Top Ten Films, Satellite Award for Best Film, Chicago Film Critics Association Award for Best Cinematography, Las Vegas Film Critics Society Award for Best Song, MTV Movie Award for Best Male Performance, Art Directors Guild Award for Excellence in Production Design for a Feature Film, Directors Guild of America Award for Outstanding Directing – Feature Film, European Film Award – Jameson People's Choice Award – Best Actress, Producers Guild of America Award for Best Theatrical Motion Picture, Amanda Award for Best Foreign Feature Film, Academy Award for Best Original Dramatic Score
#
# 14) Query: Did Iron Man pass the Bechdel test?
# Closest answer:
#         entity: Iron Man
#       property: test taken
#
#
# Answer: Bechdel test, reverse Bechdel Test
#
# 15) Query: What kind of film is Iron Man?
#
# Answer: Answer not found
#
# 16) Query: Who won the Academy Award for Best Director in 2012?
# Closest answer:
#         entity: Academy Award for Best Director
#       property: winner
#
#
# Answer: Alfonso Cuarón, Alejandro González Iñárritu, Ang Lee, Bong Joon-ho
#
# 17) Query: Where does A Star Is Born take place?
# Closest answer:
#         entity: A Star Is Born
#       property: narrative location
#
#
# Answer: Los Angeles
#
# 18) Query: Who directed A Star Is Born?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: A Star Is Born
#       property: cast member
#
#
# Answer: Lady Gaga, Dave Chappelle, Brandi Carlile, Alec Baldwin, Bradley Cooper, Bonnie Somerville, Greg Grunberg, Sam Elliott, Ron Rifkin, Eddie Griffin, Luenell, Don Was, Andrew Dice Clay, Drena De Niro, Matthew Libatique, Rafi Gavron, Rebecca Field, Michael D. Roberts, Shangela Laquifa Wadley, Michael Harney, Marlon Williams, Anthony Ramos Martinez
#
# 19) Query: How much did it cost to film Tenet?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 20) Query: In what year did the first Harry Potter movie come out?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 21) Query: What are the titles of the Harry Potter movies?
#
# Answer: Answer not found
#
# 22) Query: What is the Kijkwijzer rating of The Hitman's Bodygard?
#
# Answer: Answer not found
#
# 23) Query: When is George Clooney born?
# Closest answer:
#         entity: George Clooney
#       property: date of birth
#
#
# Answer: 1961-05-06T00:00:00Z
#
# 24) Query: How many awards did George Clooney receive?
# Closest answer:
#         entity: George Clooney
#       property: award received
#
#
# Answer: Academy Award for Best Picture, Academy Award for Best Supporting Actor, BAFTA Award for Best Film, Golden Globe Award for Best Actor – Motion Picture Musical or Comedy, Golden Globe Award for Best Actor – Motion Picture Drama, Golden Globe Cecil B. DeMille Award, Golden Globe Award for Best Supporting Actor – Motion Picture, MTV Movie Award for Best Breakthrough Performance, Saturn Award for the Best Actor, European Film Award for Best Non-European Film, National Board of Review Award for Best Film, Screen Actors Guild Award for Outstanding Performance by an Ensemble in a Drama Series, Chevalier des Arts et des Lettres, Indiana Film Journalists Association Award for Best Actor
#
# 25) Query: Which movie came after Pokemon 3: The Movie?
# Closest answer:
#         entity: Kites
#       property: director
#
#
# Answer: Anurag Basu
#
# 26) Query: Which actors have played Tony Stark?
# Closest answer:
#         entity: Tony Stark
#       property: performer
#
#
# Answer: Robert Downey Jr., Davin Ransom
#
# 27) Query: Who won the Academy Award for Best Supporting Actor in 1995?
# Closest answer:
#         entity: Academy Award for Best Director
#       property: winner
#
#
# Answer: Alfonso Cuarón, Alejandro González Iñárritu, Ang Lee, Bong Joon-ho
#
# 28) Query: What are the main subjects of the movie Taken?
#
# Answer: Error
#
# 29) Query: What was the cause of death of Alan Rickman?
# Closest answer:
#         entity: Alan Rickman
#       property: cause of death
#
#
# Answer: pancreatic cancer
#
# 30) Query: Who directed The Prestige
#
# Answer: Error
#
# 31) Query: When was the last Lord of the Rings movie released
#
# Answer: Answer not found
#
# 32) Query: Where was Pulp Fiction filmed
# Closest answer:
#         entity: Pulp Fiction
#       property: filming location
#
#
# Answer: Los Angeles
#
# 33) Query: Which awards did Blade Runner receive
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 34) Query: 1964
#
# Answer: Error
#
# 35) Query: Who composed the music for Inception
#
# Answer: Error
#
# 36) Query: What was the box office for Whiplash
#
# Answer: Error
#
# 37) Query: Who wrote the on which the Shawshank Redemption was based
# Closest answer:
#         entity: The Shawshank Redemption
#       property: main subject
#
#
# Answer: corruption, friendship, hope, imprisonment, miscarriage of justice, Incarceration in the United States, abuse of power, male bonding
#
# 38) Query: Which company produced Westworld
# Closest answer:
#         entity: Westworld
#       property: production company
#
#
# Answer: Metro-Goldwyn-Mayer
#
# 39) Query: In which aspect ratio was Kingsman: The Secret Service filmed
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 40) Query: What university did Adam Sandler attend?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 41) Query: How many Pokémon episodes are there?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 42) Query: Who are the executive producers of Suits?
#
# Answer: Answer not found
#
# 43) Query: When did the pilot episode of The Blacklist air?
#
# Answer: Error
#
# 44) Query: Who directed the 2018 biographical film about Queen?
#
# Answer: Error
#
# 45) Query: In what country was Bohemian Rhapsody released on the 31st of October, 2018?
# Closest answer:
#         entity: Bohemian Rhapsody
#       property: publication date
#
#
# Answer: 2018-10-24T00:00:00Z, 2018-10-31T00:00:00Z, 2018-11-01T00:00:00Z, 2018-11-02T00:00:00Z
#
# 46) Query: What actor received an Oscar/Academy Award for their work in Bohemian Rhapsody?
# Closest answer:
#         entity: Rhapsody
#       property: cast member
#
#
# Answer: Elizabeth Taylor, Michael Chekhov, Vittorio Gassman, Celia Lovsky, Barbara Bates, John Mylong, Stuart Whitman, Louis Calhern, John Ericson, Richard Hageman, Marion Elisabeth Degler, Madge Blake, Konstantin Shayne, Stuart Holmes, Gordon Richards, Richard Lupino
#
# 47) Query: For which Oscars/Academy Awards was the film Shrek nominated?
# Closest answer:
#         entity: Shrek
#       property: award received
#
#
# Answer: Academy Award for Best Animated Feature
#
# 48) Query: What is the Netflix ID of the film Shrek?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 49) Query: What film, directed by Bong Joon-ho, led him to receive the Academy Award for Best Director?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 50) Query: Who directed Fight Club?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 51) Query: Who are the screenwriters for The Place Beyong The Pines?
#
# Answer: Answer not found
#
# 52) Query: Who is the main character from Mad Max?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 53) Query: What is the name of the main character from Mad Max?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 54) Query: When was Al Pacino born?
# Closest answer:
#         entity: Al Pacino
#       property: date of birth
#
#
# Answer: 1940-04-25T00:00:00Z
#
# 55) Query: What genre is Midsommar?
#
# Answer: Answer not found
#
# 56) Query: How long does the movie Shot Caller take to watch?
# Closest answer:
#         entity: Shot Caller
#       property: director
#
#
# Answer: Ric Roman Waugh
#
# 57) Query: Who created the music for Interstellar?
# Closest answer:
#         entity: Interstellar
#       property: genre
#
#
# Answer: drama, adventure film, science fiction film, dystopian film, drama
#
# 58) Query: Who is the lead actor of Inception?
#
# Answer: Error
#
# 59) Query: What is the theme for Pulp Fiction?
# Closest answer:
#         entity: Pulp Fiction
#       property: main subject
#
#
# Answer: organized crime
#
# 60) Query: What is the latest Avengers movie?
# Closest answer:
#         entity: The Avengers
#       property: director
#
#
# Answer: Joss Whedon
#
# 61) Query: What's the German name of Groundhog Day?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 62) Query: Who plays the main character in The Joker?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 63) Query: In what aspect ratio was Zack Snyder's Justice League shot?
# Closest answer:
#         entity: Justice League
#       property: aspect ratio
#
#
# Answer: widescreen
#
# 64) Query: Who wrote Titanic?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 65) Query: How did the composer of Django Unchained die?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 66) Query: Who composed the music for Avatar?
# Closest answer:
#         entity: Avatar
#       property: genre
#
#
# Answer: science fiction, action film, adventure film, science fiction film, military science fiction, live-action animated film
#
# 67) Query: When was Quentin Tarantino's cinema opened?
# Closest answer:
#         entity: Death Proof
#       property: director of photography
#
#
# Answer: Quentin Tarantino
#
# 68) Query: Why did Brangelina end?
#
# Answer: Answer not found
#
# 69) Query: Who is Josey Matas famous nephew?
# Closest answer:
#         entity: Josey Matas
#       property: relative
#
#
# Answer: Seth Rogen, Mark Rogen, Sandy Rogen
#
# 70) Query: When was Steven Spielberg born?
# Closest answer:
#         entity: Steven Spielberg
#       property: date of birth
#
#
# Answer: 1946-12-18T00:00:00Z
#
# 71) Query: Who is the director of Love Actually?
# Closest answer:
#         entity: Love Actually
#       property: director
#
#
# Answer: Richard Curtis
#
# 72) Query: What is the country of origin of mr. Bean?
#
# Answer: Error
#
# 73) Query: Where was Leonardo DiCaprio born?
# Closest answer:
#         entity: Leonardo DiCaprio
#       property: date of birth
#
#
# Answer: 1974-11-11T00:00:00Z
#
# 74) Query: Who is the composer of Pirates of the Caribbean?
# Closest answer:
#         entity: Pirates of the Caribbean
#       property: composer
#
#
# Answer: Hans Zimmer
#
# 75) Query: What is the catchphrase of James Bond?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: James Bond
#       property: catchphrase
#
#
# Answer: The name is Bond, James Bond
#
# 76) Query: Who are the film editors of Titanic?
#
# Answer: Answer not found
#
# 77) Query: What is the duration of The Fault in Our Stars?
# Closest answer:
#         entity: The Fault in Our Stars
#       property: duration
#
#
# Answer: 126
#
# 78) Query: What are the genres of the movie Jaws?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Jaws
#       property: genre
#
#
# Answer: drama, thriller film, film based on a novel
#
# 79) Query: What was the filming location of the Harry Potter film series?
# Closest answer:
#         entity: Harry Potter
#       property: place of birth
#
#
# Answer: Godric’s Hollow
#
# 80) Query: Who directed Lord of The Rings?
# Closest answer:
#         entity: The Lord of the Rings: The Fellowship of the Ring
#       property: director
#
#
# Answer: Peter Jackson
#
# 81) Query: Who played the title character in 2008 film Iron Man?
# Closest answer:
#         entity: Iron Man
#       property: characters
#
#
# Answer: Phil Coulson
#
# 82) Query: Where does Die Hard take place?
# Closest answer:
#         entity: Die Hard
#       property: country of origin
#
#
# Answer: United States of America
#
# 83) Query: Who played Joker in The Dark Knight?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 84) Query: Who directed Pulp Fiction?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 85) Query: Who wrote the screenplay and played the main character for Rocky?
# Closest answer:
#         entity: Rocky
#       property: screenwriter
#
#
# Answer: Sylvester Stallone
#
# 86) Query: Who plays Forrest Gump?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 87) Query: Who were the composers for Batman Begins?
#
# Answer: Answer not found
#
# 88) Query: What is the sequel to Captain America : Winter Soldier?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 89) Query: What is the original broadcaster of Breaking Bad?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 90) Query: When was Harry Potter and the Philosopher stone publish in the US?
#
# Answer: Answer not found
#
# 91) Query: Who are the screenwriters on Avengers: Endgame?
#
# Answer: Answer not found
#
# 92) Query: Who owns Pixar?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 93) Query: Who was the first person to play James Bond?
#
# Answer: Answer not found
#
# 94) Query: What nationality does Scarlett Johansson have?
# Closest answer:
#         entity: Scarlett Johansson
#       property: country of citizenship
#
#
# Answer: United States of America, Denmark
#
# 95) Query: What was the budget for Avatar?
# Closest answer:
#         entity: Avatar
#       property: cost
#
#
# Answer: 237000000
#
# 96) Query: Who presented the Oscars in 2012?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 97) Query: When did Charlie Chaplin pass away?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 98) Query: When was the subreddit for Star Wars created?
# Closest answer:
#         entity: Star Wars
#       property: subreddit
#
#
# Answer: StarWars
#
# 99) Query: What awards did Frozen receive?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 100) Query: Who is the director of the movie Midsommar?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Midsommar
#       property: director
#
#
# Answer: Ari Aster
#
# 101) Query: What are the main subjects of the movie Tenet?
# Error while searching!
# Attempting moderated search!
#
# Answer: Answer not found
#
# 102) Query: What movie was Interstellar influenced by?
# Closest answer:
#         entity: Interstellar
#       property: influenced by
#
#
# Answer: 2001: A Space Odyssey
#
# 103) Query: Who was the composer of Inception?
# Closest answer:
#         entity: Inception
#       property: composer
#
#
# Answer: Hans Zimmer
#
# 104) Query: How much did 2001: A Space Oddyssey cost to make?
#
# Answer: Error
#
# 105) Query: For which award was the movie Climax nominated for?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 106) Query: How many episodes does Twin Peaks have?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Twin Peaks
#       property: number of episodes
#
#
# Answer: 18
#
# 107) Query: In what film format was Rosemary's Baby shot?
# Closest answer:
#         entity: Rosemary
#       property: distribution format
#
#
# Answer: video on demand
#
# 108) Query: What was the box office amount for the movie Psycho
#
# Answer: Error
#
# 109) Query: How long is the movie Mulholland Drive?
# Closest answer:
#         entity: Mulholland Drive
#       property: director
#
#
# Answer: David Lynch
#
# 110) Query: When did Leonardo DiCaprio start acting?
# Closest answer:
#         entity: Leonardo DiCaprio
#       property: work period (start)
#
#
# Answer: 1989-01-01T00:00:00Z
#
# 111) Query: Who directed Once Upon a Time in Hollywood?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 112) Query: When did Star Wars: Episode IV – A New Hope get published in the United States?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 113) Query: Which countries is Martin Scorsese a citizen in?
#
# Answer: Answer not found
#
# 114) Query: What are the names of Martin Scorsese's children?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 115) Query: Who performed the music on Interstallar?
#
# Answer: Answer not found
#
# 116) Query: What is the duration of 2001: A Space Odyssey?
# Closest answer:
#         entity: Space Odyssey
#       property: duration
#
#
# Answer: 114
#
# 117) Query: Who presented the 65th British Academy Film Awards?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 118) Query: What is the genre of Dunkirk?
# Closest answer:
#         entity: Dunkirk
#       property: genre
#
#
# Answer: drama, war film
#
# 119) Query: Which awards did Memento win?
# Closest answer:
#         entity: Memento
#       property: award received
#
#
# Answer: National Film Registry, National Board of Review: Top Ten Films
#
# 120) Query: Who is the director of the movie Forrest Gump?
# Closest answer:
#         entity: Forrest Gump
#       property: director
#
#
# Answer: Robert Zemeckis
#
# 121) Query: Who are the main two actors from the movie Titanic?
#
# Answer: Answer not found
#
# 122) Query: Who is the main actor of the movie Forrest Gump?
# Closest answer:
#         entity: Forrest Gump
#       property: cast member
#
#
# Answer: Valentine, Tiffany Salerno, Marla Sucharetza, Aloysius Gigl, Jack Bowden, Lazarus Jackson, Matt Rebenkoff, Peter Bannon, Joe Washington, Natalie Hendrix, Chiffonye Cobb, Juan Singleton, Michael Mattison, Lenny Herb, Charles Boswell, Timothy McNeil, Lonnie Hamilton, Teresa Denton, John Lennon, Tom Hanks, Gerald Ford, Hanna R. Hall, Kurt Russell, Gary Sinise, Sally Field, Robin Wright, Sam Anderson, Dick Cavett, Mary Ellen Trainor, Siobhan Fallon Hogan, Haley Joel Osment, Mykelti Williamson, Bobby Richardson, Michael Jace, Michael Conner Humphreys, Geoffrey Blake, Joe Alaskey, Sonny Shroyer, Jacqueline Lovell, John Voldstad, Afemo Omilami, Christopher Jones, Peter Dobson, Stephen Bridgewater, David Brisbin, Al Harrington, Brett Rice, Joe Stefanelli, Nora Dunfee, Vanessa Roth, Hallie D'Amore, Daniel C. Striepeke, Emily Carey, Elizabeth Hanks, W. Benson Terry, Kevin Davis, Michael Burgess, Don Fischer, Rebecca Williams, Harold G. Herthum, George Kelly, Bob Penny, John Randall, Margo Moorer, Ione M. Telech, Christine Seabrook, John Worsham, Alexander Zemeckis, Logan Livingston Gomez, Ben Waddel, Tyler Long, Grady Bowman, Kevin Mangan, Fay Genens, Frank Geyer, Rob Landry, Jason McGuire, Pete Auster, Ed Davis, Bruce Lucvia, Kirk Ward, Angela Lomas, Timothy Record, Deborah McTeer, Mark Matheisen, Jed Gillin, Bob Harks, Kenneth Bevington, Michael Flannery, Gary Robinson, Marlena Smalls, Kitty K. Green, Matt Wallace, Danté McCarthy, Paulie DiCocco, Mike Jolly, Michael Kemmerling, Jeffrey Winner, Russ Wilson, Daniel J. Gillooly, Calvin Gadsden, Aaron Izbicki, Steven Griffith, William Acy "Billy" Roberson Jr, Michael McFall, Eric Underwood, Steve DeRelian, Byron Minns, Bonnie Ann Burgess, Scott Oliver, John William Galt, Hilary Chaplain, Isabel Rose, Jay Ross, Richard D'Alessandro, Dick Stilwell, Tim Perry, Paul Raczkowski
#
# 123) Query: What is the genre of the movie Interstellar?
# Closest answer:
#         entity: Interstellar
#       property: genre
#
#
# Answer: drama, adventure film, science fiction film, dystopian film, drama
#
# 124) Query: What is the date of birth of the actress Natalie Portman?
# Closest answer:
#         entity: Natalie Portman
#       property: date of birth
#
#
# Answer: 1981-06-09T00:00:00Z
#
# 125) Query: What is the main subject of the movie Interstellar?
# Closest answer:
#         entity: Interstellar
#       property: main subject
#
#
# Answer: interstellar travel
#
# 126) Query: In what year was the movie Interstellar released?
# Closest answer:
#         entity: Interstellar
#       property: director
#
#
# Answer: Christopher Nolan
#
# 127) Query: When did the awarded actress Katharine Hepburn die?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 128) Query: What are the genres of the movie The Breakfast Club?
# Closest answer:
#         entity: The Breakfast Club
#       property: genre
#
#
# Answer: drama, comedy-drama, teen film, coming-of-age story
#
# 129) Query: What is the original language of movie Anna Karenina?
# Closest answer:
#         entity: Anna Karenina
#       property: original language of film or TV show
#
#
# Answer: English
#
# 130) Query: Who directed The Shining?
#
# Answer: Error
#
# 131) Query: What is the runtime of The Godfather?
# Closest answer:
#         entity: The Godfather
#       property: platform
#
#
# Answer: DOS
#
# 132) Query: Does Casablanca have a website?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 133) Query: Does Solaris pass the Bechdel test?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 134) Query: How many cast members are in 12 angry men?
#
# Answer: Error
#
# 135) Query: What did it cost to make Blade Runner?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 136) Query: Was Harrison Ford in Apocalypse Now?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 137) Query: Did Samuel L. Jackson produce Pulp Fiction?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 138) Query: Is Nicolas Cage Nicolas Cage's real name, if no, what is it?
# Error while searching!
# Attempting moderated search!
#
# Answer: Answer not found
#
# 139) Query: What is Gone With The Wind about?
#
# Answer: Error
#
# 140) Query: Who is the voice actor of Darth Vader in Star Wars?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 141) Query: When did Kung Fu Panda came out as a movie?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 142) Query: Who are the members of the Teenage Mutant Ninja Turtles?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 143) Query: Who is the director of Pulp Fiction?
# Closest answer:
#         entity: Pulp Fiction
#       property: director
#
#
# Answer: Quentin Tarantino
#
# 144) Query: Who is an enemy of Bilbo Baggins?
#
# Answer: Answer not found
#
# 145) Query: Who is the father of Simba?
# Closest answer:
#         entity: Simba
#       property: father
#
#
# Answer: Mufasa
#
# 146) Query: What is the duration of I Am Legend?
# Closest answer:
#         entity: Legend
#       property: instance of
#
#
# Answer: film
#
# 147) Query: What genre is The Hangover?
#
# Answer: Answer not found
#
# 148) Query: Who is Batman?
#
# Answer: Answer not found
#
# 149) Query: Where does Guy Ritchie come from?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 150) Query: Han Solo was played by which actor in Star Wars: Episode IV – A New Hope?
# Closest answer:
#         entity: Han Solo
#       property: performer
#
#
# Answer: Harrison Ford, Alden Ehrenreich
#
# 151) Query: Who directed The Dark Knight?
# Closest answer:
#         entity: The Dark Knight
#       property: director
#
#
# Answer: Christopher Nolan
#
# 152) Query: Which famous composer created music for Inception?
#
# Answer: Error
#
# 153) Query: How many movies are included in the Harry Potter series?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 154) Query: Where was Slumdog Millionaire filmed?
# Closest answer:
#         entity: Slumdog Millionaire
#       property: filming location
#
#
# Answer: Mumbai
#
# 155) Query: When was The Shawshank Redemption published in Germany?
# Closest answer:
#         entity: The Shawshank Redemption
#       property: publication date
#
#
# Answer: 1994-09-10T00:00:00Z, 1994-09-23T00:00:00Z, 1995-03-01T00:00:00Z, 1995-03-09T00:00:00Z, 1995-07-06T00:00:00Z
#
# 156) Query: What is the name of the character played by Al Pacino in The Godfather?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 157) Query: Which movies are in the The Lord of the Rings trilogy?
#
# Answer: Answer not found
#
# 158) Query: What are the languages spoken in Steven Cameron's Avatar?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 159) Query: To which genres does Avengers: Endgame belong?
# Closest answer:
#         entity: Belong
#       property: genre
#
#
# Answer: ambient music, shoegaze, drone
#
# 160) Query: Who are the founders of Pixar Animation Studios?
# Closest answer:
#         entity: Pixar
#       property: founded by
#
#
# Answer: Edwin Catmull, Alvy Ray Smith
#
# 161) Query: What caused the death of Walt Disney?
# Closest answer:
#         entity: Walt Disney
#       property: date of death
#
#
# Answer: 1966-02-15T00:00:00Z, 1966-12-15T00:00:00Z
#
# 162) Query: How many followers does Studio Ghibli have on social media?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Studio Ghibli
#       property: social media followers
#
#
# Answer: 334187
#
# 163) Query: When was the movie A Silent Voice publicated in Germany?
# Closest answer:
#         entity: A Silent Voice
#       property: director
#
#
# Answer: Naoko Yamada
#
# 164) Query: At which locations was The Intouchables filmed?
#
# Answer: Answer not found
#
# 165) Query: Who was the director of Kimi no Na wa?
# Closest answer:
#         entity: KIMI
#       property: director
#
#
# Answer: Steven Soderbergh
#
# 166) Query: Who won the Oscar for Best Supporting Actor in 2013?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: The Oscar
#       property: Academy Awards Database film ID
#
#
# Answer: 3025
#
# 167) Query: What is the name of the dad of Steven Spielberg?
# Closest answer:
#         entity: Steven Spielberg
#       property: given name
#
#
# Answer: Steven
#
# 168) Query: To which genres does Weathering with You belong?
#
# Answer: Error
#
# 169) Query: Who narrated The Big Lebowski?
# Closest answer:
#         entity: The Big Lebowski
#       property: narrator
#
#
# Answer: Sam Elliott
#
# 170) Query: What is the name of Thor's hammer in the Avengers?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 171) Query: Who founded the Walt Disney Animation Studios?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 172) Query: When did the TV-series Doctor Who first start?
#
# Answer: Error
#
# 173) Query: Where is Jurassic Park located in the film from 1993?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 174) Query: What is the catchphrase of the fictional character James Bond?
# Closest answer:
#         entity: James Bond
#       property: catchphrase
#
#
# Answer: The name is Bond, James Bond
#
# 175) Query: What are the titles of the three parts of the Lord of the Rings trilogy?
#
# Answer: Answer not found
#
# 176) Query: Who played the character Marty McFly in the Back to the Future trilogy?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 177) Query: What was the name of the beer consumed by character in the Harry Potter universe?
# Closest answer:
#         entity: Harry Potter
#       property: given name
#
#
# Answer: Harry
#
# 178) Query: Who was the director of the film Avatar?
# Closest answer:
#         entity: Avatar
#       property: director
#
#
# Answer: James Cameron
#
# 179) Query: Who composed the music for the 2001 film Amelie?
# Closest answer:
#         entity: Amélie
#       property: genre
#
#
# Answer: drama, comedy film, romantic comedy, magic realist film
#
# 180) Query: Who is the director of The Hangover?
# Closest answer:
#         entity: The Hangover
#       property: director
#
#
# Answer: Todd Phillips
#
# 181) Query: What is spider-man's name?
#
# Answer: Error
#
# 182) Query: When did Stan Lee die?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 183) Query: Who is Elizabeth Keen's father?
# Closest answer:
#         entity: Elizabeth Keen
#       property: father
#
#
# Answer: Raymond Reddington
#
# 184) Query: How long is Bridge of Spies?
# Closest answer:
#         entity: Bridge of Spies
#       property: duration
#
#
# Answer: 142
#
# 185) Query: Who acted as James Bond?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 186) Query: Who directed Bridge of Spies?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 187) Query: Where is Captain America from?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 188) Query: When was Robert Langdon born?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 189) Query: Where was Angels and Demons filmed?
#
# Answer: Answer not found
#
# 190) Query: Who composed the music for The Lord of the Rings: The Fellowship of the Ring?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: The Lord of the Rings
#       property: genre
#
#
# Answer: fantasy film, traditionally animated film, film based on a novel
#
# 191) Query: Who played Obi-Wan in the Star Wars prequel trilogy?
#
# Answer: Answer not found
#
# 192) Query: Which movies are in the Star Wars prequel trilogy?
#
# Answer: Answer not found
#
# 193) Query: Which awards did The Platform win?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 194) Query: Which company distributed The Platform?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 195) Query: Who made the Skyfall theme song?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 196) Query: Which languages does Hayden Christensen speak?
# Closest answer:
#         entity: Hayden Christensen
#       property: languages spoken, written or signed
#
#
# Answer: Spanish
#
# 197) Query: When was the first Star Wars Movie released?
# Closest answer:
#         entity: Star Wars sequel trilogy
#       property: director
#
#
# Answer: J. J. Abrams, Rian Johnson
#
# 198) Query: Who played Hitler in Der Untergang?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 199) Query: Which movies did John Williams compose music for?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 200) Query: What year were the first Academy Awards hosted?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 201) Query: Who are the cast members in The Lighhouse?
#
# Answer: Answer not found
#
# 202) Query: Where was The Seventh Seal filmed?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 203) Query: What is the original language of Memories of Murder?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 204) Query: Who directed the movie 8 1/2?
#
# Answer: Error
#
# 205) Query: How long is The Holy Mountain?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 206) Query: What is the first line of Citizen Kane?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 207) Query: Who won the Academy Award for Best Film in 2020?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Academy Award for Best Director
#       property: winner
#
#
# Answer: Alfonso Cuarón, Alejandro González Iñárritu, Ang Lee, Bong Joon-ho
#
# 208) Query: When was Stalker released?
# Closest answer:
#         entity: Stalker
#       property: publication date
#
#
# Answer: 1979-05-25T00:00:00Z
#
# 209) Query: What are the genres of Whiplash?
# Closest answer:
#         entity: Whiplash
#       property: genre
#
#
# Answer: drama, musical film
#
# 210) Query: Who is the creator of the TV series "Succession"?
#
# Answer: Error
#
# 211) Query: What are the narrative locations (cities) in the movie "Lost in Translation"?
#
# Answer: Error
#
# 212) Query: Who was a music composer in the movie "Interstellar"?
#
# Answer: Answer not found
#
# 213) Query: What are the names of the "Lord of the Ring" trilogy?
#
# Answer: Answer not found
#
# 214) Query: For what movie Meryl Streep received her first Academy Award?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 215) Query: What production company created the animated movie "Finding Nemo"?
# Closest answer:
#         entity: Finding Nemo
#       property: production company
#
#
# Answer: Pixar
#
# 216) Query: Where did the film director Martin Scorsese was born?
# Closest answer:
#         entity: Martin Scorsese
#       property: date of birth
#
#
# Answer: 1942-11-17T00:00:00Z
#
# 217) Query: How much did the production of the movie "Inglourious Basterds" (2009) cost?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 218) Query: When was the first movie "Kill Bill" released?
#
# Answer: Answer not found
#
# 219) Query: Who was the screenwriter of the "Social Media"?
#
# Answer: Answer not found
#
# 220) Query: Where was the movie "Who killed captain Alex" filmed?
# Closest answer:
#         entity: Filmed in Supermarionation
#       property: director
#
#
# Answer: Stephen La Rivière
#
# 221) Query: Who was the lead actor in "Tenet"?
#
# Answer: Answer not found
#
# 222) Query: When was "Kill Bill" first premiered?
#
# Answer: Answer not found
#
# 223) Query: Who wrote the score for the movie Interstellar?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 224) Query: What was the duration of Bladerunner 2049?
#
# Answer: Answer not found
#
# 225) Query: What was the budget of the 2009 movie, Avatar?
# Closest answer:
#         entity: Avatar
#       property: cost
#
#
# Answer: 237000000
#
# 226) Query: Who directed James Bond: Skyfall?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 227) Query: When did Quentin Tarantino first start working on movies?
# Closest answer:
#         entity: Quentin Tarantino
#       property: work period (start)
#
#
# Answer: 1983-01-01T00:00:00Z
#
# 228) Query: What is the twitter username of the Japanese TV series, Doraemon?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 229) Query: What is Christopher Nolan an instance of?
#
# Answer: Answer not found
#
# 230) Query: Who composed the music Pirates of the Caribbean?
# Closest answer:
#         entity: Pirates of the Caribbean
#       property: genre
#
#
# Answer: pirate film, action comedy film
#
# 231) Query: Who played Obi-Wan Kenobi in Star Wars?
#
# Answer: Answer not found
#
# 232) Query: What are the roles that Samuel L. Jackson played in the Star Wars franchise and the Marvel Cinamatic Universe?
#
# Answer: Answer not found
#
# 233) Query: Which performers have been in the role of Anakin Skywalker?
#
# Answer: Answer not found
#
# 234) Query: How much time does it cost to watch The Karate Kid from 1984?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 235) Query: At what coordinates can we find a big sign that states 'Hollywood'?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 236) Query: List all the actors that have played James Bond?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 237) Query: What was the box office of Avatar in the United States?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 238) Query: What are the names of the four members of the A-team?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 239) Query: On what date did the actor playing Brian O'Conner in The Fast and the Furious die?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 240) Query: When was the first James Bond movie released?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 241) Query: Who wrote the books on which the Bourne Trilogy was based?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 242) Query: What genre is the movie Saving Private Ryan?
#
# Answer: Answer not found
#
# 243) Query: Who directed the first Shrek movie?
#
# Answer: Error
#
# 244) Query: Did Tommy Lee Jones star in the movie the Fugitive?
# Closest answer:
#         entity: Tommy Lee Jones
#       property: work period (start)
#
#
# Answer: 1969-01-01T00:00:00Z
#
# 245) Query: When was Harrison Ford born?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 246) Query: Who composed the music for the Star Wars Trilogy?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 247) Query: What is the Dutch age rating for the movie Bohemian Rhapsody?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 248) Query: What is the main subject of the movie I, Robot?
# Closest answer:
#         entity: Enthiran
#       property: main subject
#
#
# Answer: android
#
# 249) Query: Which role did Will Smith play in I, Robot?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 250) Query: What is Quentin Tarantino's date of birth?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 251) Query: Who played in Inception?
# Closest answer:
#         entity: Inception
#       property: performer
#
#
# Answer: Hans Zimmer
#
# 252) Query: Where did Leonardo DiCaprio go to school?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 253) Query: How long is the movie Iron Man?
# Closest answer:
#         entity: Iron Man
#       property: director
#
#
# Answer: Jon Favreau
#
# 254) Query: Who created Star Wars?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 255) Query: When was Interstellar released?
# Closest answer:
#         entity: Interstellar
#       property: publication date
#
#
# Answer: 2014-10-26T00:00:00Z, 2014-11-05T00:00:00Z, 2014-11-06T00:00:00Z, 2014-11-07T00:00:00Z
#
# 256) Query: Where was Mark Ruffalo born?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 257) Query: How tall is Bryan Cranston?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 258) Query: What languages does Christoph Waltz speak?
# Closest answer:
#         entity: Christoph Waltz
#       property: languages spoken, written or signed
#
#
# Answer: French, German, English
#
# 259) Query: Who is the director of Fury?
#
# Answer: Error
#
# 260) Query: How many awards has Quentin Tarentino won?
#
# Answer: Answer not found
#
# 261) Query: When was The Shawshank Redemption released in the United States?
# Closest answer:
#         entity: The Shawshank Redemption
#       property: publication date
#
#
# Answer: 1994-09-10T00:00:00Z, 1994-09-23T00:00:00Z, 1995-03-01T00:00:00Z, 1995-03-09T00:00:00Z, 1995-07-06T00:00:00Z
#
# 262) Query: Who played Freddie Mercury in Bohemian Rhapsody?
# Closest answer:
#         entity: Freddie Mercury
#       property: instrument
#
#
# Answer: piano, guitar, keyboard instrument, Hammond organ, voice
#
# 263) Query: How many minutes long is The Wolf of Wall Street?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 264) Query: In what year is The Revenant set?
#
# Answer: Answer not found
#
# 265) Query: From what country does the movie T-34 originate?
#
# Answer: Error
#
# 266) Query: What are the main subjects of Saving Private Ryan?
#
# Answer: Answer not found
#
# 267) Query: What is the box office of 8 Mile?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 268) Query: What is the Kijkwijzer rating of IT?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 269) Query: Who directed the 1990 movie Tremors?
# Closest answer:
#         entity: Tremors
#       property: director
#
#
# Answer: Ron Underwood
#
# 270) Query: Who is Tom Hanks currently married to?
#
# Answer: Answer not found
#
# 271) Query: In 1996 Nicolas Cage won an Academy Award for Best Actor, which work was it for?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 272) Query: What MPAA film rating did The Matrix receive?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 273) Query: Who were the screenwriters of Team America: World Police?
#
# Answer: Answer not found
#
# 274) Query: What is the German label for the 1968 Sergio Leone film Once Upon a Time in the West?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 275) Query: What is the film Dr. Strangelove also known as in English?
# Closest answer:
#         entity: Dr. Strangelove
#       property: genre
#
#
# Answer: comedy film, war film, satirical film, black comedy film, film based on a novel
#
# 276) Query: What was the filming location of the film Metropolis?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 277) Query: The 2011 film Tinker Tailor Soldier Spy is made after a work by whom?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 278) Query: How tall is the actor Toby Jones?
# Closest answer:
#         entity: Toby Jones
#       property: height
#
#
# Answer: 1.65
#
# 279) Query: Who directed Minari?
# Closest answer:
#         entity: Minari
#       property: director
#
#
# Answer: Lee Isaac Chung
#
# 280) Query: Who won the Oscar for best actress in the 77th Academy Awards?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 281) Query: Where did It Happened One Night take place?
#
# Answer: Error
#
# 282) Query: How many awards has Ryan Reynolds earned?
# Closest answer:
#         entity: Ryan Reynolds
#       property: award received
#
#
# Answer: Saturn Award, MTV Movie & TV Awards, MTV Movie Award for Best Fight, Canada's Walk of Fame, Governor General's Performing Arts Awards
#
# 283) Query: Who directed photography for Gravity?
# Closest answer:
#         entity: Gravity
#       property: director
#
#
# Answer: Alfonso Cuarón
#
# 284) Query: What year was Grave of the Fireflies initially released?
# Closest answer:
#         entity: Grave of the Fireflies
#       property: publication date
#
#
# Answer: 1988-01-01T00:00:00Z
#
# 285) Query: The Matrix series currently has three movies. What is the last one called?
# Closest answer:
#         entity: The Matrix
#       property: part of the series
#
#
# Answer: The Matrix trilogy
#
# 286) Query: How much did the most expensive movie to produce cost?
#
# Answer: Error
#
# 287) Query: What genre is the Netflix Death Note movie?
#
# Answer: Answer not found
#
# 288) Query: What country won the oscar for best foreign film in 2020?
#
# Answer: Error
#
# 289) Query: When was Tom Hanks born?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 290) Query: Who are the children of Shrek?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 291) Query: How much did Inception cost to produce?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 292) Query: How long is Shrek Forever After?
#
# Answer: Error
#
# 293) Query: Which movie won the Academy Award for Best Picture in 2020?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 294) Query: Where was Forrest Gump produced?
# Closest answer:
#         entity: Forrest Gump
#       property: producer
#
#
# Answer: Wendy Finerman, Steve Starkey, Charles Newirth, Steve Tisch
#
# 295) Query: Who directed The Room?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 296) Query: Who composed the music for Slumdog Millionaire?
# Closest answer:
#         entity: Slumdog Millionaire
#       property: genre
#
#
# Answer: drama, crime film, romance film, coming-of-age story, film based on a novel
#
# 297) Query: What films are in the Unbreakable movie series?
#
# Answer: Answer not found
#
# 298) Query: How tall is Amitabh Bachchan?
# Closest answer:
#         entity: Amitabh Bachchan
#       property: height
#
#
# Answer: 1.88
#
# 299) Query: For which movie did Greta Gerwig receive an Academy Award nomination?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 300) Query: When did Leonardo DiCario win an Oscar?
#
# ...
#
#
# Answer: 1.88
#
# 1046) Query: Who holds the record of most awards won?
#
# Answer: Error
#
# 1047) Query: Who directed Hellboy?
# Closest answer:
#         entity: Hellboy
#       property: director
#
#
# Answer: Guillermo del Toro
#
# 1048) Query: What are the names of the Coen Brothers?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1049) Query: Who directed the movie that won the "Best Actress" award at 91st Acadeny Awards in 2018?
# Closest answer:
#         entity: Gofmaniada
#       property: director
#
#
# Answer: Stanislav Sokolov
#
# 1050) Query: What is the name of the third movie of the Lord of the Rings trilogy?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1051) Query: Who played Ron Weasley in the Harry Potter movies?
# Closest answer:
#         entity: Harry Potter
#       property: member of sports team
#
#
# Answer: Gryffindor quidditch team
#
# 1052) Query: Which movie is the Disaster Artist about?
# Closest answer:
#         entity: The Disaster Artist
#       property: director
#
#
# Answer: James Franco
#
# 1053) Query: What is the name of the Alfonso Cuaron movie, released in 2018?
# Closest answer:
#         entity: Alfonso Cuarón
#       property: given name
#
#
# Answer: Alfonso
#
# 1054) Query: Of which trilogy is Hot Fuzz a part of?
#
# Answer: Answer not found
#
# 1055) Query: What is the name of the mockumentary movie, starring the Lonely Island?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1056) Query: Which TV series is the Naked Gun trilogy based on?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1057) Query: Who directed the movie "The Lion King"?
# Closest answer:
#         entity: The Lion King
#       property: director
#
#
# Answer: Roger Allers, Rob Minkoff
#
# 1058) Query: Who composed the music for the netflix original movie 'Polar'?
# Closest answer:
#         entity: Polar
#       property: genre
#
#
# Answer: drama, action film, adventure film, crime film, thriller film
#
# 1059) Query: For which awards was the work of Hans Zimmer in the movie 'Interstellar' nominated?
# Closest answer:
#         entity: Interstellar
#       property: award received
#
#
# Answer: Academy Award for Best Visual Effects
#
# 1060) Query: Which movies did Christopher Nolan direct?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1061) Query: Where did the story of 'Ford v Ferrari' take place?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1062) Query: What movie genre is the movie 'Pineapple express'?
#
# Answer: Error
#
# 1063) Query: Who is in the cast of the movie 'Bad Trip'?
#
# Answer: Answer not found
#
# 1064) Query: Which awards did the movie 'Uncut Gems' win?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Uncut Gems
#       property: award received
#
#
# Answer: National Board of Review: Top Ten Films
#
# 1065) Query: Which movie followed 'Star Wars: Episode IV - A New Hope'?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1066) Query: Who played the main role of Arthur Fleck in the 2019 release of 'Joker'?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1067) Query: For what film did Guillermo del Toro win the Academy Award for best director?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1068) Query: Hayao Miyazaki, director of the Oscar winning "Spirited Away" was born in what year?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1069) Query: The Three Flavours Cornetto trilogy, directed by Edgar Wright contains which three films?
# Closest answer:
#         entity: Three Flavours Cornetto trilogy
#       property: has part
#
#
# Answer: The World's End, Hot Fuzz, Shaun of the Dead
#
# 1070) Query: What color is actor Michael Sheen's hair?
# Closest answer:
#         entity: Michael Sheen
#       property: hair color
#
#
# Answer: brown hair
#
# 1071) Query: What is the combined duration of all films in the Underworld series?
# Closest answer:
#         entity: Underworld
#       property: duration
#
#
# Answer: 121
#
# 1072) Query: What genre(s) is the film Free Fire?
#
# Answer: Answer not found
#
# 1073) Query: The character Galadriel from the Lord of the Rings series has been played by which two actresses?
# Closest answer:
#         entity: Galadriel
#       property: performer
#
#
# Answer: Cate Blanchett, Morfydd Clark
#
# 1074) Query: What locations is the film Colossal set in?
# Answer: Error
#
# 1075) Query: When was Anne Hathaway born?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Anne Hathaway
#       property: date of birth
#
#
# Answer: 1982-11-12T00:00:00Z
#
# 1076) Query: What time periods is City of God set in?
#
# Answer: Answer not found
#
# 1077) Query: On what book is Apocalypse Now based?
#
# Answer: Error
#
# 1078) Query: How much did Titanic cost to make?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Titanic
#       property: cost
#
#
# Answer: 200000000
#
# 1079) Query: What language is spoken in Parasite?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1080) Query: How many children does David Lynch have?
# Closest answer:
#         entity: David Lynch
#       property: child
#
#
# Answer: Jennifer Lynch, Austin Jack Lynch, Lula Boginia Lynch, Riley Sweeney Lynch
#
# 1081) Query: Who directed The Big Lebowski?
# Closest answer:
#         entity: The Big Lebowski: A XXX Parody
#       property: director
#
#
# Answer: Lee Roy Myers
#
# 1082) Query: For what movie has Martin Scorsese won an oscar?
# Closest answer:
#         entity: Martin Scorsese
#       property: Academy Awards Database nominee ID
#
#
# Answer: 561
#
# 1083) Query: What movie from Andrei Tarkovsky came out in 1972?
# Closest answer:
#         entity: Andrei Tarkovsky
#       property: MovieMeter director ID (former scheme)
#
#
# Answer: 31021
#
# 1084) Query: Who composed the music for Dunkirk?
# Closest answer:
#         entity: Dunkirk
#       property: genre
#
#
# Answer: drama, war film
#
# 1085) Query: Which company distributed Alien?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1086) Query: Which oscars did Guillermo del Toro's 2017 film win?
# Closest answer:
#         entity: Guillermo del Toro
#       property: Academy Awards Database nominee ID
#
#
# Answer: 4809
#
# 1087) Query: Which film series about Middle-earth did Peter Jackson direct?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1088) Query: What movie genre is The Impossible?
#
# Answer: Error
#
# 1089) Query: What is the name of the first film of the Star Trek film series?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Star Trek is…
#       property: language of work or name
#
#
# Answer: English
#
# 1090) Query: Who was the voice actor of E.T.?
# Closest answer:
#         entity: E.T. the Extra-Terrestrial
#       property: cast member
#
#
# Answer: Debra Winger, Erika Eleniak, Dee Wallace, Peter Coyote, James Kahn, Tamara De Treaux, Anne Lockhart, C. Thomas Howell, Henry Thomas, Drew Barrymore, Robert MacNaughton, K. C. Martel, Sean Frye, Milt Kogan, Robert Barton
#
# 1091) Query: When was Adurey Hepburn born?
#
# Answer: Answer not found
#
# 1092) Query: For which films did Cate Blanchett receive an Academy Award?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1093) Query: When was Parasite released?
# Closest answer:
#         entity: Parasite
#       property: publication date
#
#
# Answer: 2019-05-21T00:00:00Z
#
# 1094) Query: In which country was the director of Parasite born?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1095) Query: Who plays Frodo Baggings in The Lord of the Rings: the Two Towers?
#
# Answer: Answer not found
#
# 1096) Query: What movie inspired The Matrix?
# Closest answer:
#         entity: The Matrix
#       property: director
#
#
# Answer: The Wachowskis
#
# 1097) Query: What film genre is the Titanic?
#
# Answer: Answer not found
#
# 1098) Query: Who directed the Titanic?
# Closest answer:
#         entity: Titanic
#       property: director
#
#
# Answer: James Cameron
#
# 1099) Query: What year did the film Finding Nemo come out?
# Closest answer:
#         entity: Finding Nemo
#       property: genre
#
#
# Answer: comedy film, adventure film, family film
#
# 1100) Query: By what company was the film Tarzan directed?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1101) Query: What country is the film Lion King originally from?
#
# Answer: Answer not found
#
# 1102) Query: What is the publication date of the film Fifty Shades of Grey?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1103) Query: Who is the screenwriter of Fifty Shades of Grey?
# Closest answer:
#         entity: Fifty Shades of Grey
#       property: screenwriter
#
#
# Answer: Kelly Marcel
#
# 1104) Query: Who are the main characters of Fifty Shades of Grey?
# Closest answer:
#         entity: Fifty Shades of Grey
#       property: characters
#
#
# Answer: Anastasia Steele
#
# 1105) Query: What is the main subject of the film I spit on your grave?
#
# Answer: Error
#
# 1106) Query: How long is the film I spit on your grave?
#
# Answer: Error
#
# 1107) Query: Who voiced Ozai in Avatar: The Last Airbender?
# Closest answer:
#         entity: The Legend of Korra
#       property: voice actor
#
#
# Answer: J. K. Simmons, Zelda Williams, Seychelle Gabriel, Mindy Sterling, Jeff Bennett, Henry Rollins, David Faustino, Kiernan Shipka, April Stewart, Steven Yeun, Dee Bradley Baker, Steve Blum, John Michael Higgins, Janet Varney, Jonathan Adams, Greg Baldwin, Jim Meskimen, P. J. Byrne, Tim Hedrick, Skyler Brigmann
#
# 1108) Query: In what year was James Cameron's Avatar released?
# Closest answer:
#         entity: Avatar
#       property: publication date
#
#
# Answer: 2009-12-16T00:00:00Z, 2009-12-17T00:00:00Z, 2009-12-18T00:00:00Z
#
# 1109) Query: Who are the creators of Glee?
# Closest answer:
#         entity: Glee
#       property: creator
#
#
# Answer: Brad Falchuk, Ryan Murphy, Ian Brennan
#
# 1110) Query: How many "How To Train Your Dragon" movies are there?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1111) Query: Which movies are part of the "How To Train Your Dragon" franchise?
#
# Answer: Answer not found
#
# 1112) Query: Who plays the role of Tony Almeida in 24?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1113) Query: When is Jack Bauer's birthday?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1114) Query: What's the IMDb ID of the series 24?
# Closest answer:
#         entity: 24
#       property: IMDb ID
#
#
# Answer: tt4981966
#
# 1115) Query: Who is married to Shrek?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Shrek
#       property: spouse
#
#
# Answer: Princess Fiona
#
# 1116) Query: Who played a lead role in both Riverdale and the Suite Life of Zack and Cody?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1117) Query: What is the actor Jack Nicholson's date of birth?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1118) Query: Who is Lars von Trier?
#
# Answer: Answer not found
#
# 1119) Query: What is most notable work from the American composer John Williams?
#
# Answer: Answer not found
#
# 1120) Query: When was the American romantic disaster film Titanic released?
# Closest answer:
#         entity: The American
#       property: genre
#
#
# Answer: thriller film, film based on a novel
#
# 1121) Query: What is the famous phrase from the movie Forrest Gump?
#
# Answer: Answer not found
#
# 1122) Query: Who created Star Wars?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1123) Query: What are the names of the episodes in the Harry Potter film series?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1124) Query: How many Academy Awards has Meryl Streep won so far?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1125) Query: What else is the actor Arnold Schwarzenegger known for?
#
# Answer: Answer not found
#
# 1126) Query: Where was The Lord of the Rings trilogy filmed?
#
# Answer: Answer not found
#
# 1127) Query: When was Leonardo di caprio born?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1128) Query: Who directed the movie Fight Club?
# Closest answer:
#         entity: Fight Club
#       property: director
#
#
# Answer: David Fincher
#
# 1129) Query: When was the movie Fight Club released for the first time?
# Closest answer:
#         entity: Fight Club
#       property: director
#
#
# Answer: David Fincher
#
# 1130) Query: When was the academy awards Oscars organised for the first time?
#
# Answer: Error
#
# 1131) Query: Who is the founder and creator of Star Wars?
# Closest answer:
#         entity: Star Wars
#       property: founded by
#
#
# Answer: George Lucas
#
# 1132) Query: Who directed The Shawshank Redemption?
# Closest answer:
#         entity: The Shawshank Redemption
#       property: director
#
#
# Answer: Frank Darabont
#
# 1133) Query: What's the name of Batman?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1134) Query: When was Brad Pitt born?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1135) Query: Where was Christopher Nolan born?
# Closest answer:
#         entity: Christopher Nolan
#       property: date of birth
#
#
# Answer: 1970-07-30T00:00:00Z
#
# 1136) Query: What is Christopher Nolan's middle name?
# Closest answer:
#         entity: Christopher Nolan
#       property: given name
#
#
# Answer: Edward, Christopher
#
# 1137) Query: Who was the director of the movie "Star Wars: Episode IV – A New Hope"?
# Closest answer:
#         entity: Star Wars: Episode IV – A New Hope
#       property: director
#
#
# Answer: George Lucas
#
# 1138) Query: What actor played the role of "Legolas" in the "The Lord of the Rings" trilogy?
# Closest answer:
#         entity: Rings
#       property: cast member
#
#
# Answer: Zach Roerig, Daveigh Chase, Aimee Teegarden, Johnny Galecki, Vincent D'Onofrio, Laura Slade Wiggins, Lizzie Brocheré, Bonnie Morgan, Matilda Anna Ingrid Lutz, Alex Roe, Kayli Carter, Andrea Powell
#
# 1139) Query: Where was the movie "Pulp Fiction" filmed?
# Closest answer:
#         entity: Pulp Fiction
#       property: director
#
#
# Answer: Quentin Tarantino
#
# 1140) Query: What awards did the movie "Joker" receive?
# Closest answer:
#         entity: Joker
#       property: director
#
#
# Answer: Todd Phillips
#
# 1141) Query: Where does the action take place in the movie "1917"?
#
# Answer: Error
#
# 1142) Query: Henry Cavill played which fictional character in the movie "Zack Snyder's Justice League"?
# Error while searching!
# Attempting moderated search!
# Closest answer:
#         entity: Justice League
#       property: characters
#
#
# Answer: Justice League
#
# 1143) Query: In what year was the movie "The Dark Knight" released?
#
# Answer: Answer not found
#
# 1144) Query: Who composed the music for the movie "Interstellar"?
# Error while searching!
# Attempting moderated search!
# Error while searching!
#
# Answer: Answer not found
#
# 1145) Query: How long is the movie "Once Upon a Time in Hollywood"?
# Closest answer:
#         entity: Once Upon a Time
#       property: director
#
#
# Answer: Zhao Xiaoding
#
# 1146) Query: In what period is the action of the movie "Gladiator" set in?
#
# Answer: Answer not found
#
# Questions queried: 1147
# Not found ratio: 0.6190061028770706

# %%
print(pipeline("Is Leonardo DiCaprio an actor?"))
# Out:
# Answer not found

# %%
import pandas as pd
df = pd.read_csv('answerlist.txt', sep='|')

print('Questions that could not be answered:')
filtered = (df[df['Answer']=='Answer not found'])

for index, row in filtered.iterrows():
    print(row["Query"])
# Out:
# Questions that could not be answered:
# What movie won best picture in the 2020 Academy Awards?
# Who voices Nala in the 2019 version of The Lion King?
# Which is the longest Jim Carrey movie?
# What movie(s) feature both Jack Nicholson and Meryl Streep?
# Which director has been nominated most for the Best Director Academy Award?
# What movie(s) did M. Night Shyamalan direct before the year 2000?
# Which actors have portrayed the character James Bond?
# Where was Titanic shot?
# What kind of film is Iron Man?
# How much did it cost to film Tenet?
# In what year did the first Harry Potter movie come out?
# What are the titles of the Harry Potter movies?
# What is the Kijkwijzer rating of The Hitman's Bodygard?
# When was the last Lord of the Rings movie released
# Which awards did Blade Runner receive
# In which aspect ratio was Kingsman: The Secret Service filmed
# What university did Adam Sandler attend?
# How many Pokémon episodes are there?
# Who are the executive producers of Suits?
# What is the Netflix ID of the film Shrek?
# What film, directed by Bong Joon-ho, led him to receive the Academy Award for Best Director?
# Who directed Fight Club?
# Who are the screenwriters for The Place Beyong The Pines?
# Who is the main character from Mad Max?
# What is the name of the main character from Mad Max?
# What genre is Midsommar?
# What's the German name of Groundhog Day?
# Who plays the main character in The Joker?
# Who wrote Titanic?
# How did the composer of Django Unchained die?
# Why did Brangelina end?
# Who are the film editors of Titanic?
# Who played Joker in The Dark Knight?
# Who directed Pulp Fiction?
# Who plays Forrest Gump?
# Who were the composers for Batman Begins?
# What is the sequel to Captain America : Winter Soldier?
# What is the original broadcaster of Breaking Bad?
